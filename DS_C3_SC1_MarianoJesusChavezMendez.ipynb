# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Metadata = pd.read_csv('/content/0.9ep3krj7s1o0.ona2jvufk4mMetadata.csv',encoding='UTF-8-sig',sep=',')
Metadata
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 258          XKX       Europe & Central Asia  Upper middle income
# 259          YEM  Middle East & North Africa           Low income
# 260          ZAF          Sub-Saharan Africa  Upper middle income
# 261          ZMB          Sub-Saharan Africa  Lower middle income
# 262          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName
# 0                                                  NaN         Aruba
# ...

# %%
Happiness_report = pd.read_csv('/content/0.rw6r6mdtjng0.9sxn8dzeqsbHappiness_report.csv',encoding='UTF-8-sig',sep=',')
Happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
Happiness_World = Happiness_report
Happiness_World = Happiness_World.set_index('Country or region')
Happiness_World.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
Happiness_Mexico = Happiness_report[Happiness_report['Country or region']=='Mexico']
Happiness_Mexico = Happiness_Mexico.set_index('Country or region')
Happiness_Mexico.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Mexico                       23  6.595            1.07           1.323
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Mexico                               0.861                         0.433
#
#                    Generosity  Perceptions of corruption
# Country or region
# Mexico                  0.074                      0.073

# %%
value = Happiness_Mexico.loc['Mexico','Score']
value
# Out:
# np.float64(6.595)

# %%
sns.set_style('white')
props_bbox = {'boxstyle': 'circle','facecolor': 'red','edgecolor':'black','alpha': 0.5}

sns.histplot(x='Score',data=Happiness_World,legend=True)
plt.title('World Happiness Report', fontsize=14, weight='bold')
plt.ylabel('Frequency')

value = Happiness_Mexico.loc['Mexico','Score']
plt.text(value,1,'Mex',color='white',bbox=props_bbox)

plt.show()

# %%
mex_value = Happiness_Mexico.loc[Happiness_Mexico.index=='Mexico','Healthy life expectancy'].to_list()[0]
mex_value
# Out:
# 0.861

# %%
sns.set_style('white')

props_bbox = {'boxstyle': 'circle','facecolor': 'red','edgecolor':'black','alpha': 0.5}
props_arrow = {'arrowstyle':'->','color':'black'}

sns.catplot(kind='box',y='Healthy life expectancy',color='white',data=Happiness_report,orient='h',capprops=dict(color='black')
,flierprops=dict(marker='o', markerfacecolor='white', markersize=10, markeredgecolor='black'))

mex_value = Happiness_Mexico.loc[Happiness_Mexico.index=='Mexico','Healthy life expectancy'].to_list()[0]

plt.title('World Happiness Report', fontsize=14, weight='bold')
plt.xlabel('Healthy Life Expectancy')
plt.ylabel('')

plt.annotate('MEX', xy=(0,mex_value),xytext=(0.5,mex_value+0.1),color='white',arrowprops=props_arrow,bbox=props_bbox)

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py:1601: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))

# %%
Happiness_MexicoPie = Happiness_Mexico
Happiness_MexicoPie = Happiness_MexicoPie.T
Happiness_MexicoPie = Happiness_MexicoPie.loc[Happiness_MexicoPie.index!='Overall rank']
Happiness_MexicoPie = Happiness_MexicoPie.loc[Happiness_MexicoPie.index!='Score']
Happiness_MexicoPie.columns = ['Factors']
Happiness_MexicoPie.index.name = 'Values'
Happiness_MexicoPie.head()

Happiness_MexicoPie1 = Happiness_MexicoPie.T
Happiness_MexicoPie1.head()
# Out:
# Values   GDP per capita  Social support  Healthy life expectancy  \
# Factors            1.07           1.323                    0.861
#
# Values   Freedom to make life choices  Generosity  Perceptions of corruption
# Factors                         0.433       0.074                      0.073

# %%
sns.set_style('white')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10), gridspec_kw={'width_ratios': [1, 3]})
fig.suptitle('Contribution in Mexico happines score',fontsize=16)


table = ax1.table(cellText=Happiness_MexicoPie1.T.values,rowLabels=Happiness_MexicoPie1.columns,colLabels=Happiness_MexicoPie1.index,loc='lower left')
table.auto_set_font_size(False)
table.scale(1.2, 1.2)
ax1.axis('off')


Happiness_MexicoPie['Factors'].plot(kind='pie',autopct='%1.1f%%',ax=ax2)
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
Happiness_WorldTopTwo = Happiness_World.sort_values(by='Overall rank',ascending=True)
Happiness_WorldTopTwo = Happiness_WorldTopTwo.iloc[:2]
Happiness_WorldTopMexico = Happiness_World.loc[Happiness_World.index=='Mexico']
countries = ('Canada','United States')
Happiness_WorldTopAddTwo = Happiness_World.loc[Happiness_World.index.isin(countries)]

# %%
Happiness_WorldTop = pd.concat([Happiness_WorldTopTwo,Happiness_WorldTopMexico,Happiness_WorldTopAddTwo])
Happiness_WorldTop = Happiness_WorldTop.reset_index()
Happiness_WorldTop
# Out:
#   Country or region  Overall rank  Score  GDP per capita  Social support  \
# 0           Finland             1  7.769           1.340           1.587
# 1           Denmark             2  7.600           1.383           1.573
# 2            Mexico            23  6.595           1.070           1.323
# 3            Canada             9  7.278           1.365           1.505
# 4     United States            19  6.892           1.433           1.457
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    0.861                         0.433       0.074
# 3                    1.039                         0.584       0.285
# 4                    0.874                         0.454       0.280
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
Happiness_WorldTop = pd.concat([Happiness_WorldTopTwo,Happiness_WorldTopMexico,Happiness_WorldTopAddTwo])
Happiness_WorldTop = Happiness_WorldTop.reset_index()
Happiness_WorldTop = Happiness_WorldTop.melt(id_vars='Country or region',var_name='Factors',value_name='Values')
Happiness_WorldTop = Happiness_WorldTop.loc[Happiness_WorldTop['Factors']!='Overall rank']
Happiness_WorldTop = Happiness_WorldTop.loc[Happiness_WorldTop['Factors']!='Score']
Happiness_WorldTop.head()
# Out:
#    Country or region         Factors  Values
# 10           Finland  GDP per capita   1.340
# 11           Denmark  GDP per capita   1.383
# 12            Mexico  GDP per capita   1.070
# 13            Canada  GDP per capita   1.365
# 14     United States  GDP per capita   1.433

# %%
sns.set_style('white')

sns.barplot(x='Factors', y='Values', hue='Country or region', data=Happiness_WorldTop)
plt.xticks(rotation=90)
plt.title('World Happiness Report', fontsize=14, weight='bold')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
Happiness_World.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
fig = plt.figure(figsize=(20,10))
fig.suptitle('Contribution in happiness score',fontsize=16)

ax1 = fig.add_subplot(231)
splot = sns.scatterplot(x='Score',y='GDP per capita',data=Happiness_World,ax=ax1)

ax2 = fig.add_subplot(232)
splot = sns.scatterplot(x='Score',y='Social support',data=Happiness_World,ax=ax2)

ax3 = fig.add_subplot(233)
splot = sns.scatterplot(x='Score',y='Healthy life expectancy',data=Happiness_World,ax=ax3)

ax4 = fig.add_subplot(234)
splot = sns.scatterplot(x='Score',y='Freedom to make life choices',data=Happiness_World,ax=ax4)

ax5 = fig.add_subplot(235)
splot = sns.scatterplot(x='Score',y='Generosity',data=Happiness_World,ax=ax5)

ax6 = fig.add_subplot(236)
splot = sns.scatterplot(x='Score',y='Perceptions of corruption',data=Happiness_World,ax=ax6)

# %%
corrGDPpercapita = Happiness_World['GDP per capita'].corr(Happiness_World['Score'])
corrGDPpercapita
# Out:
# np.float64(0.7938828678781275)

# %%
corrSocialsupport = Happiness_World['Social support'].corr(Happiness_World['Score'])
corrSocialsupport
# Out:
# np.float64(0.7770577880638644)

# %%
corrHealthylifeexpectancy = Happiness_World['Healthy life expectancy'].corr(Happiness_World['Score'])
corrHealthylifeexpectancy
# Out:
# np.float64(0.7798831492425828)

# %%
corrFreedomtomakelifechoices = Happiness_World['Freedom to make life choices'].corr(Happiness_World['Score'])
corrFreedomtomakelifechoices
# Out:
# np.float64(0.5667418257199898)

# %%
corrGenerosity = Happiness_World['Generosity'].corr(Happiness_World['Score'])
corrGenerosity
# Out:
# np.float64(0.07582369490389651)

# %%
corrPerceptionsofcorruption = Happiness_World['Perceptions of corruption'].corr(Happiness_World['Score'])
corrPerceptionsofcorruption
# Out:
# np.float64(0.38561307086647856)

# %%
Happiness_World.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
sns.heatmap(round(Happiness_World.corr(),2),annot=True)
# Out:
# <Axes: >

# %%
Metadata.set_index('TableName',inplace=True)
Metadata.head()
# Out:
#             Country Code                     Region          IncomeGroup  \
# TableName
# Aruba                ABW  Latin America & Caribbean          High income
# Afghanistan          AFG                 South Asia           Low income
# Angola               AGO         Sub-Saharan Africa  Lower middle income
# Albania              ALB      Europe & Central Asia  Upper middle income
# Andorra              AND      Europe & Central Asia          High income
#
#             SpecialNotes
# TableName
# Aruba                NaN
# Afghanistan          NaN
# Angola               NaN
# Albania              NaN
# Andorra              NaN

# %%
Happiness_WorldxMetadata = pd.merge(left=Happiness_World,right=Metadata,left_index=True,right_index=True)
Happiness_WorldxMetadata.reset_index(inplace=True)
Happiness_WorldxMetadata.head()
# Out:
#          index  Overall rank  Score  GDP per capita  Social support  \
# 0      Finland             1  7.769           1.340           1.587
# 1      Denmark             2  7.600           1.383           1.573
# 2       Norway             3  7.554           1.488           1.582
# 3      Iceland             4  7.494           1.380           1.624
# 4  Netherlands             5  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption Country Code                 Region  IncomeGroup  \
# ...

# %%
colums=['Region','Score']
Happiness_WorldxMetadata = Happiness_WorldxMetadata[colums]
Happiness_WorldxMetadata = Happiness_WorldxMetadata.groupby('Region').mean('Score')
Happiness_WorldxMetadata.head()
# Out:
#                                Score
# Region
# East Asia & Pacific         5.658769
# Europe & Central Asia       6.104174
# Latin America & Caribbean   6.007579
# Middle East & North Africa  5.757429
# North America               7.085000

# %%
sns.set_style('white')
sns.set_palette('pastel')

Happiness_WorldxMetadata.plot(kind='bar',legend=False)
plt.title('World Happiness Report', fontsize=14, weight='bold')
# Out:
# Text(0.5, 1.0, 'World Happiness Report')
