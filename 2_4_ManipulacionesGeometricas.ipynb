# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point, LineString, Polygon
import geopandas as gpd
from geopandas import GeoDataFrame
from geopandas import GeoSeries
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
## metodos constructivos

figures = gpd.GeoSeries([Point(0, 0),LineString([(1, -1), (1, 0), (2, 0), (2, 1)]),Polygon([(3, -1), (4, 0), (3, 1)]),])

# %%
figures.plot()
# Out:
# <Axes: >

# %%
figures.buffer(0.2).plot()
# Out:
# <Axes: >

# %%
figures.buffer(0.2,resolution=2).plot()
# Out:
# <Axes: >

# %%
figures.buffer(0.2,cap_style=2).plot()
# Out:
# <Axes: >

# %%
figures.buffer(0.2,cap_style=3).plot()
# Out:
# <Axes: >

# %%
figures.buffer(0.2,join_style=2).plot()
# Out:
# <Axes: >

# %%
figures.buffer(0.2,join_style=3).plot()
# Out:
# <Axes: >

# %%
figures.boundary
# Out:
# 0             GEOMETRYCOLLECTION EMPTY
# 1           MULTIPOINT ((1 -1), (2 1))
# 2    LINESTRING (3 -1, 4 0, 3 1, 3 -1)
# dtype: geometry

# %%
figures.plot()
# Out:
# <Axes: >

# %%
figures.centroid
# Out:
# 0          POINT (0 0)
# 1        POINT (1.5 0)
# 2    POINT (3.33333 0)
# dtype: geometry

# %%
figures.centroid.plot()
# Out:
# <Axes: >

# %%
figures.convex_hull.plot()
# Out:
# <Axes: >

# %%
figures.envelope.plot()
# Out:
# <Axes: >

# %%
figures.simplify(1).plot()
# Out:
# <Axes: >

# %%
figures.unary_union
# Out:
# <ipython-input-23-9c19ca22c124>:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   figures.unary_union
# <GEOMETRYCOLLECTION (POINT (0 0), LINESTRING (1 -1, 1 0, 2 0, 2 1), POLYGON ...>

# %%
figures2 = gpd.GeoSeries([Point(1, 1),LineString([(2, -1), (1, -1), (1, 0)]),Polygon([(3, -1), (4, 0), (3, 1)]),])

# %%
figures2.plot()
# Out:
# <Axes: >

# %%
figures2.rotate(90, origin=(0,0) ).plot()
# Out:
# <Axes: >

# %%
figures2.rotate(90, origin='centroid').plot()
# Out:
# <Axes: >

# %%
figures2.scale(1.2,1.5, origin=(0,0)).plot()
# Out:
# <Axes: >

# %%
figures2.scale(1.2,1.5, origin='centroid').plot()
# Out:
# <Axes: >

# %%
figures2.skew(30,0).plot()
# Out:
# <Axes: >

# %%
figures2.skew(0,15).plot()
# Out:
# <Axes: >

# %%
figures2.skew(30,15).plot()
# Out:
# <Axes: >

# %%
figures2.translate(1,0).plot()
# Out:
# <Axes: >

# %%
figures2.translate(3,2).plot()
# Out:
# <Axes: >
