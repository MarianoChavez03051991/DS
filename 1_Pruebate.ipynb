# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
population = pd.read_csv('/content/1695677925032-Fertility.csv',encoding='UTF-8-sig',sep=',')
population.head()
# Out:
#   Country Name Country Code   1960   1961   1962   1963   1964   1965   1966  \
# 0        Aruba          ABW  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# 1  Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2       Angola          AGO  6.708  6.790  6.872  6.954  7.036  7.116  7.194
# 3      Albania          ALB  6.489  6.401  6.282  6.133  5.960  5.773  5.581
# 4      Andorra          AND    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1967  ...   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  3.417  ...  1.761  1.768  1.779  1.795  1.813  1.834  1.854  1.872  1.886
# 1  7.450  ...  6.180  5.977  5.770  5.562  5.359  5.163  4.976  4.800  4.633
# 2  7.267  ...  6.260  6.194  6.120  6.039  5.953  5.864  5.774  5.686  5.600
# 3  5.394  ...  1.652  1.660  1.673  1.684  1.690  1.688  1.677  1.659  1.638
# 4    NaN  ...  1.190  1.270    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     2018
# 0  1.896
# 1  4.473
# ...

# %%
mexico = population.loc[population['Country Name']=='Mexico']
mexico = mexico.drop(['Country Code'],axis=1)
mexico = mexico.set_index('Country Name')
mexico = mexico.T
mexico.columns = ['Fertility']
mexico.index.name = 'Year'
mexico.head()
# Out:
#       Fertility
# Year
# 1960      6.769
# 1961      6.768
# 1962      6.770
# 1963      6.775
# 1964      6.780

# %%
mexico.plot(title = 'Fertility rate in Mexico',style = '--')
plt.grid(True, color='blue')

# %%
MexicoCanada = population.loc[(population['Country Name']=='Mexico')|(population['Country Name']=='Canada')]
MexicoCanada = MexicoCanada.drop(['Country Code'],axis=1)
MexicoCanada = MexicoCanada.set_index('Country Name')
MexicoCanada = MexicoCanada.T
#MexicoCanada.columns = ['Fertility']
#MexicoCanada.index.name = 'Year'
MexicoCanada.head()
# Out:
# Country Name  Canada  Mexico
# 1960           3.811   6.769
# 1961           3.753   6.768
# 1962           3.681   6.770
# 1963           3.607   6.775
# 1964           3.456   6.780

# %%
MexicoCanada.plot(title = 'Fertility rate',style = '--')
plt.grid(True, color='gray')

# %%
countries = ['Mexico', 'United States', 'China', 'India', 'Somalia']
Top5 = population.loc[population['Country Name'].isin(countries), ['Country Name', '2018']]
Top5 = Top5.set_index('Country Name')
#Top5 = Top5.T
#MexicoCanada.columns = ['Fertility']
#MexicoCanada.index.name = 'Year'
Top5.head()
# Out:
#                  2018
# Country Name
# China          1.6900
# India          2.2220
# Mexico         2.1290
# Somalia        6.0720
# United States  1.7295

# %%
Top5.plot(title = 'Fertility rate',style = '-',rot=90)
plt.grid(True, color='gray')
