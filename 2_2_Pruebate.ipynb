# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point, LineString, Polygon
import geopandas as gpd
from geopandas import GeoDataFrame
from geopandas import GeoSeries

# %%
Costco = pd.read_csv('/content/0.zdgkinsx62h0.lyo4ulpsaectiendaCostco.csv',encoding='UTF-8-sig',sep=',')
Costco.head()
# Out:
#    id          nombre                       direccion          ubicacion  \
# 0   1        "Puebla"     Blvd. del Niño Poblano 2904             Puebla
# 1   2   "Villa Coapa"                      Puente 186              Coapa
# 2   3    "Cuernavaca"        Av. Vicente Guerrero 205         Cuernavaca
# 3   4    "Lindavista"      Av. Insurgentes Norte 1320  Gustavo A. Madero
# 4   5       "Mixcoac"  Blvd. Adolfo López Mateos 1181     Alvaro Obregón
#
#      latitud   longitud  tel centro llantero
# 0  19.033499 -98.237794         222 2273 318
# 1  19.284359 -99.138655                  NaN
# 2  18.934481 -99.233430         777 7101 523
# 3  19.481697 -99.130063         55 5747 5691
# 4  19.387237 -99.190718                  NaN

# %%
Costco.columns = Costco.columns.str.strip()
Costco.head()
# Out:
#    id          nombre                       direccion          ubicacion  \
# 0   1        "Puebla"     Blvd. del Niño Poblano 2904             Puebla
# 1   2   "Villa Coapa"                      Puente 186              Coapa
# 2   3    "Cuernavaca"        Av. Vicente Guerrero 205         Cuernavaca
# 3   4    "Lindavista"      Av. Insurgentes Norte 1320  Gustavo A. Madero
# 4   5       "Mixcoac"  Blvd. Adolfo López Mateos 1181     Alvaro Obregón
#
#      latitud   longitud tel centro llantero
# 0  19.033499 -98.237794        222 2273 318
# 1  19.284359 -99.138655                 NaN
# 2  18.934481 -99.233430        777 7101 523
# 3  19.481697 -99.130063        55 5747 5691
# 4  19.387237 -99.190718                 NaN

# %%
gdf = GeoDataFrame(Costco, geometry=GeoSeries.from_xy(Costco.longitud,Costco.latitud))
gdf.head()
# Out:
#    id          nombre                       direccion          ubicacion  \
# 0   1        "Puebla"     Blvd. del Niño Poblano 2904             Puebla
# 1   2   "Villa Coapa"                      Puente 186              Coapa
# 2   3    "Cuernavaca"        Av. Vicente Guerrero 205         Cuernavaca
# 3   4    "Lindavista"      Av. Insurgentes Norte 1320  Gustavo A. Madero
# 4   5       "Mixcoac"  Blvd. Adolfo López Mateos 1181     Alvaro Obregón
#
#      latitud   longitud tel centro llantero                    geometry
# 0  19.033499 -98.237794        222 2273 318   POINT (-98.23779 19.0335)
# 1  19.284359 -99.138655                 NaN  POINT (-99.13865 19.28436)
# 2  18.934481 -99.233430        777 7101 523  POINT (-99.23343 18.93448)
# 3  19.481697 -99.130063        55 5747 5691   POINT (-99.13006 19.4817)
# 4  19.387237 -99.190718                 NaN  POINT (-99.19072 19.38724)

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
puntos_conectados = Polygon(zip(gdf['longitud'],gdf['latitud']))
puntos_conectados
# Out:
# <POLYGON ((-98.238 19.033, -99.139 19.284, -99.233 18.934, -99.13 19.482, -9...>

# %%
gdf.total_bounds
# Out:
# array([-117.0289102 ,   17.9663734 ,  -86.83546   ,   32.60663671])

# %%
Poligono = Polygon([(-135,-51.7963),(178.0653,-59.7963),(178.0653,71.7069),(-135,71.7069)])
Poligono
# Out:
# <POLYGON ((-135 -51.796, 178.065 -59.796, 178.065 71.707, -135 71.707, -135 ...>

# %%
Poligono.contains(puntos_conectados)
# Out:
# True

# %%
print(Poligono.contains(puntos_conectados))
# Out:
# True
