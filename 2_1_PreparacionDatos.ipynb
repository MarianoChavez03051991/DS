# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Costco = pd.read_csv('/content/0.zdgkinsx62h0.lyo4ulpsaectiendaCostco.csv',encoding='UTF-8-sig',sep=',')
Costco.head()
# Out:
#    id          nombre                       direccion          ubicacion  \
# 0   1        "Puebla"     Blvd. del Niño Poblano 2904             Puebla
# 1   2   "Villa Coapa"                      Puente 186              Coapa
# 2   3    "Cuernavaca"        Av. Vicente Guerrero 205         Cuernavaca
# 3   4    "Lindavista"      Av. Insurgentes Norte 1320  Gustavo A. Madero
# 4   5       "Mixcoac"  Blvd. Adolfo López Mateos 1181     Alvaro Obregón
#
#      latitud   longitud  tel centro llantero
# 0  19.033499 -98.237794         222 2273 318
# 1  19.284359 -99.138655                  NaN
# 2  18.934481 -99.233430         777 7101 523
# 3  19.481697 -99.130063         55 5747 5691
# 4  19.387237 -99.190718                  NaN

# %%
Costco.columns = Costco.columns.str.strip()
Costco['fecha actual'] = pd.Timestamp.now()

# %%
## conocer valores NaN o None en el dataframe
CostcoNulls = Costco.isnull()
CostcoNulls.head()
# Out:
#       id  nombre  direccion  ubicacion  latitud  longitud  \
# 0  False   False      False      False    False     False
# 1  False   False      False      False    False     False
# 2  False   False      False      False    False     False
# 3  False   False      False      False    False     False
# 4  False   False      False      False    False     False
#
#    tel centro llantero  fecha actual
# 0                False         False
# 1                 True         False
# 2                False         False
# 3                False         False
# 4                 True         False

# %%
print(Costco.columns.tolist())
# Out:
# ['id', 'nombre', 'direccion', 'ubicacion', 'latitud', 'longitud', 'tel centro llantero']

# %%
## por columna

Costco['nombre'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: nombre, dtype: bool

# %%
## notnull()

Costco['nombre'].notnull().head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: nombre, dtype: bool

# %%
## dropna()

Costco['nombre'] = Costco['nombre'].dropna()
Costco['nombre'].head()
# Out:
# 0         "Puebla"
# 1    "Villa Coapa"
# 2     "Cuernavaca"
# 3     "Lindavista"
# 4        "Mixcoac"
# Name: nombre, dtype: object

# %%
## .fillna()

Costco['nombre'].fillna('sin nombre').head()
# Out:
# 0         "Puebla"
# 1    "Villa Coapa"
# 2     "Cuernavaca"
# 3     "Lindavista"
# 4        "Mixcoac"
# Name: nombre, dtype: object

# %%
## replace(np.nan)

Costco['nombre'].replace(np.nan,'sin nombre').head()
# Out:
# 0         "Puebla"
# 1    "Villa Coapa"
# 2     "Cuernavaca"
# 3     "Lindavista"
# 4        "Mixcoac"
# Name: nombre, dtype: object

# %%
## interplolate

Costco['nombre'] = Costco['nombre'].interpolate(method='linear',direction='forward')
Costco['nombre'].head()
# Out:
# <ipython-input-64-e2c4ac7b4fe6>:3: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   Costco['nombre'] = Costco['nombre'].interpolate(method='linear',direction='forward')
# 0         "Puebla"
# 1    "Villa Coapa"
# 2     "Cuernavaca"
# 3     "Lindavista"
# 4        "Mixcoac"
# Name: nombre, dtype: object

# %%
Costco.head()
# Out:
#    id         nombre                       direccion          ubicacion  \
# 0   1       "Puebla"     Blvd. del Niño Poblano 2904             Puebla
# 1   2  "Villa Coapa"                      Puente 186              Coapa
# 2   3   "Cuernavaca"        Av. Vicente Guerrero 205         Cuernavaca
# 3   4   "Lindavista"      Av. Insurgentes Norte 1320  Gustavo A. Madero
# 4   5      "Mixcoac"  Blvd. Adolfo López Mateos 1181     Alvaro Obregón
#
#      latitud   longitud tel centro llantero               fecha actual
# 0  19.033499 -98.237794        222 2273 318 2025-04-23 15:39:12.112641
# 1  19.284359 -99.138655                 NaN 2025-04-23 15:39:12.112641
# 2  18.934481 -99.233430        777 7101 523 2025-04-23 15:39:12.112641
# 3  19.481697 -99.130063        55 5747 5691 2025-04-23 15:39:12.112641
# 4  19.387237 -99.190718                 NaN 2025-04-23 15:39:12.112641

# %%
Costco['fecha actual'] = pd.to_datetime(Costco['fecha actual'])
Costco['fecha actual'].head()
# Out:
# 0   2025-04-23 15:39:12.112641
# 1   2025-04-23 15:39:12.112641
# 2   2025-04-23 15:39:12.112641
# 3   2025-04-23 15:39:12.112641
# 4   2025-04-23 15:39:12.112641
# Name: fecha actual, dtype: datetime64[us]

# %%
Costco['nombre'].drop_duplicates().head()
# Out:
# 0         "Puebla"
# 1    "Villa Coapa"
# 2     "Cuernavaca"
# 3     "Lindavista"
# 4        "Mixcoac"
# Name: nombre, dtype: object

# %%
## para cambiar el string

str.lower()
str.upper()
str.capitalize()
str.title()
